# %% [markdown]
# # Fetching Movie Data
#
# Our current dataset contains 90,000 movies, but it only includes their TMDB id as well as the IMDB id. To enrich this dataset, we will fetch their details using the TMDB API.

# %%
import pandas as pd
import requests
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

import warnings
warnings.filterwarnings('ignore')

import os
from dotenv import load_dotenv
# Load the environment variables .env
load_dotenv()
# Out:
# True

# %% [markdown]
# The links csv files has 3 columns:
#
# - `movieId`: the inner id
# - `imdbId`: the id that the movie has on IMDB
# - `tmdbId`: the id that the movie has on TMDB
#
# We will keep only `movieId` and `tmdbId`

# %%
mdf = pd.read_csv('../data/raw/links.csv')
mdf.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
mdf.shape
# Out:
# (87585, 3)

# %%
# Check how many null values we have
mdf.isna().sum()
# Out:
# movieId      0
# imdbId       0
# tmdbId     124
# dtype: int64

# %%
# Check if there are duplicated values 
mdf[mdf.duplicated(subset=['tmdbId'], keep=False)].sort_values(by='tmdbId').head(10)
# Out:
#        movieId   imdbId   tmdbId
# 5892      6003   290538   4912.0
# 34340   144606   270288   4912.0
# 10103    34330   368089   9775.0
# 49943   178755   376800   9775.0
# 4138      4241   266860  10991.0
# 47959   174533   235679  10991.0
# 5562      5672   313487  12600.0
# 47964   174543   287635  12600.0
# 61157   202599  1016268  13020.0
# 9897     33154   413845  13020.0

# %% [markdown]
# We will perform the following actions:
#
# - Remove any duplicate entries based on the TMDB ID.
# - Drop the IMDB ID column, as it will not be used in the analysis.
# - Remove rows that don't have a valid TMDB ID.
# - Convert the TMDB ID column to integers for consistency.
# - Rename the TMDB ID column to "id" in preparation for fetching the movie data.

# %%
mdf.drop_duplicates(subset=['tmdbId'], inplace=True) 
mdf.drop(columns='imdbId', inplace=True)  
mdf.dropna(subset=['tmdbId'], inplace=True)  
mdf['tmdbId'] = mdf['tmdbId'].astype('int')
mdf.rename(columns={'tmdbId': 'id'}, inplace=True)
mdf.head()
# Out:
#    movieId     id
# 0        1    862
# 1        2   8844
# 2        3  15602
# 3        4  31357
# 4        5  11862

# %% [markdown]
# ## Fetch the details of the films with the TMDB API

# %%
ids = mdf['id'].values
ids.shape
# Out:
# (87425,)

# %%
def fetch_movie(movie_id, api_key):
    """
    Function to fetch data for a single movie from TMDB API
    Args:
        movie_id (int): ID of the movie
        api_key (str): API key for authentication

    Returns:
        dict: Movie data if request is successful, None if failed
    """
    url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={api_key}"
    try:
        response = requests.get(url)
        if response.status_code == 200:
            return response.json()
        else:
            return None  # Return None if response code is not 200 (success)
    
    except requests.exceptions.RequestException as e:
        # Handle any network-related or request errors
        print(f"Error fetching data for movie ID {movie_id}: {e}")
        return None

# %%
def fetch_movies(ids, api_key):
    """
    Function to fetch movie data for multiple movie IDs using concurrent requests
    Args:
        ids (list): List of movie IDs to fetch
        api_key (str): API key for authentication
    
    Returns:
        tuple: A tuple containing two lists:
            - List of successfully fetched movies (as JSON)
            - List of movie IDs for which fetching data failed
    """
    id_errors = [] 
    movies = [] 

    # Using ThreadPoolExecutor to send multiple requests concurrently
    with ThreadPoolExecutor(max_workers=10) as executor:
        # Submitting the fetch_movie function to the executor for each movie ID
        futures = {executor.submit(fetch_movie, movie_id, api_key): movie_id for movie_id in ids}

        # Processing results as they complete
        for future in as_completed(futures):
            movie_id = futures[future]
            movie_data = future.result()
            
            if movie_data:
                movies.append(movie_data)
            else:
                id_errors.append(movie_id)
            
            # Adding a small sleep time to avoid hitting API rate limits
            time.sleep(0.005)

    return movies, id_errors

# %%
api_key = os.getenv('tmdb_api_key')
movies, id_errors = fetch_movies(ids, api_key)

print(f"Fetched {len(movies)} movies")
print(f"Failed to fetch {len(id_errors)} movies")
# Out:
# Error fetching data for movie ID 121986: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Read timed out. (read timeout=None)
# Error fetching data for movie ID 18146: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Read timed out. (read timeout=None)
# Error fetching data for movie ID 37348: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Read timed out. (read timeout=None)
# Error fetching data for movie ID 103205: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Read timed out. (read timeout=None)
# Error fetching data for movie ID 259611: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Read timed out. (read timeout=None)
# Error fetching data for movie ID 483366: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Read timed out. (read timeout=None)
# Error fetching data for movie ID 965145: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Read timed out. (read timeout=None)
# Error fetching data for movie ID 913825: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Read timed out. (read timeout=None)
# Error fetching data for movie ID 891447: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Read timed out. (read timeout=None)
# Fetched 86279 movies
# Failed to fetch 1146 movies

# %% [markdown]
# ## Convert Successful Fetches to DataFrame
#
# Convert the movies for which we successfully retrieved details into a DataFrame. Afterward, we will concatenate this DataFrame with the rest of the movie dataset.

# %%
fetched = pd.DataFrame(data=movies)
fetched.head().transpose()
# Out:
#                                                                        0  \
# adult                                                              False
# backdrop_path                           /jP8lHNHD89xaRPfAdyz5KEVYcSb.jpg
# belongs_to_collection                                               None
# budget                                                                 0
# genres                 [{'id': 10751, 'name': 'Family'}, {'id': 28, '...
# homepage
# id                                                                 45325
# imdb_id                                                        tt0112302
# origin_country                                                      [US]
# original_language                                                     en
# original_title                                              Tom and Huck
# overview               A mischievous young boy, Tom Sawyer, witnesses...
# popularity                                                        0.7729
# poster_path                             /bMY31ikEOIPOHqQwhPhII8UVBln.jpg
# production_companies   [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-12-22
# revenue                                                         23920048
# runtime                                                               97
# spoken_languages       [{'english_name': 'English', 'iso_639_1': 'en'...
# status                                                          Released
# tagline                A lot of kids get into trouble. These two inve...
# title                                                       Tom and Huck
# video                                                              False
# vote_average                                                         5.3
# vote_count                                                           198
#
#                                                                        1  \
# adult                                                              False
# backdrop_path                           /oMGV48EGhsNavC1PL8HMeWs5Udq.jpg
# belongs_to_collection                                               None
# budget                                                          58000000
# genres                 [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# homepage
# id                                                                 11860
# imdb_id                                                        tt0114319
# origin_country                                                      [US]
# original_language                                                     en
# original_title                                                   Sabrina
# overview               Sabrina Fairchild, a chauffeur's daughter, gre...
# popularity                                                         2.038
# poster_path                              /i8PbLJDPU7vCwwscWD625oHbJy.jpg
# production_companies   [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
# production_countries   [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
# release_date                                                  1995-12-15
# revenue                                                         53672080
# runtime                                                              127
# spoken_languages       [{'english_name': 'French', 'iso_639_1': 'fr',...
# status                                                          Released
# tagline                You are cordially invited to the most surprisi...
# title                                                            Sabrina
# video                                                              False
# vote_average                                                       6.215
# vote_count                                                           649
#
#                                                                        2  \
# adult                                                              False
# backdrop_path                           /lEsjVrGU21BeJjF5AF9EWsihDpw.jpg
# belongs_to_collection  {'id': 96871, 'name': 'Father of the Bride (St...
# budget                                                                 0
# genres                 [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# homepage
# id                                                                 11862
# imdb_id                                                        tt0113041
# origin_country                                                      [US]
# original_language                                                     en
# original_title                               Father of the Bride Part II
# overview               Just when George Banks has recovered from his ...
# popularity                                                        1.6479
# poster_path                             /rj4LBtwQ0uGrpBnCELr716Qo3mw.jpg
# production_companies   [{'id': 9195, 'logo_path': '/geK5QOBsXIPGHutKw...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-12-08
# revenue                                                         76594107
# runtime                                                              106
# spoken_languages       [{'english_name': 'English', 'iso_639_1': 'en'...
# status                                                          Released
# tagline                Just when his world is back to normal... he's ...
# title                                        Father of the Bride Part II
# video                                                              False
# vote_average                                                       6.252
# vote_count                                                           763
#
#                                                                        3  \
# adult                                                              False
# backdrop_path                           /wPSHboBNEInknw4VnCWOD2D8qc2.jpg
# belongs_to_collection                                               None
# budget                                                          35000000
# genres                 [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# homepage
# id                                                                  9091
# imdb_id                                                        tt0114576
# origin_country                                                      [US]
# original_language                                                     en
# original_title                                              Sudden Death
# overview               When a man's daughter is suddenly taken during...
# popularity                                                        2.5257
# poster_path                             /1pylO6YX5XdOA6QCc5IRxrrffkg.jpg
# production_companies   [{'id': 99689, 'logo_path': None, 'name': 'Sha...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-10-27
# revenue                                                         64350171
# runtime                                                              110
# spoken_languages       [{'english_name': 'English', 'iso_639_1': 'en'...
# status                                                          Released
# tagline                                       Terror goes into overtime.
# title                                                       Sudden Death
# video                                                              False
# vote_average                                                       5.999
# vote_count                                                           757
#
#                                                                        4
# adult                                                              False
# backdrop_path                           /1o4vuCHpmd4DXofMYDUwpnhKiuy.jpg
# belongs_to_collection  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                          25000000
# genres                 [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage
# id                                                                 15602
# imdb_id                                                        tt0113228
# origin_country                                                      [US]
# original_language                                                     en
# original_title                                          Grumpier Old Men
# overview               A family wedding reignites the ancient feud be...
# popularity                                                        2.9176
# poster_path                             /1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg
# production_companies   [{'id': 19464, 'logo_path': None, 'name': 'Lan...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-12-22
# revenue                                                         71500000
# runtime                                                              101
# spoken_languages       [{'english_name': 'English', 'iso_639_1': 'en'...
# status                                                          Released
# tagline                Still Yelling. Still Fighting. Still Ready for...
# title                                                   Grumpier Old Men
# video                                                              False
# vote_average                                                       6.467
# vote_count                                                           403

# %% [markdown]
# Finally, we will merge the fetched movie data with their corresponding original movie_id to ensure consistency and accuracy.

# %%
final_df = pd.merge(fetched, mdf, on='id')
final_df.head().transpose()
# Out:
#                                                                        0  \
# adult                                                              False
# backdrop_path                           /jP8lHNHD89xaRPfAdyz5KEVYcSb.jpg
# belongs_to_collection                                               None
# budget                                                                 0
# genres                 [{'id': 10751, 'name': 'Family'}, {'id': 28, '...
# homepage
# id                                                                 45325
# imdb_id                                                        tt0112302
# origin_country                                                      [US]
# original_language                                                     en
# original_title                                              Tom and Huck
# overview               A mischievous young boy, Tom Sawyer, witnesses...
# popularity                                                        0.7729
# poster_path                             /bMY31ikEOIPOHqQwhPhII8UVBln.jpg
# production_companies   [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-12-22
# revenue                                                         23920048
# runtime                                                               97
# spoken_languages       [{'english_name': 'English', 'iso_639_1': 'en'...
# status                                                          Released
# tagline                A lot of kids get into trouble. These two inve...
# title                                                       Tom and Huck
# video                                                              False
# vote_average                                                         5.3
# vote_count                                                           198
# movieId                                                                8
#
#                                                                        1  \
# adult                                                              False
# backdrop_path                           /oMGV48EGhsNavC1PL8HMeWs5Udq.jpg
# belongs_to_collection                                               None
# budget                                                          58000000
# genres                 [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# homepage
# id                                                                 11860
# imdb_id                                                        tt0114319
# origin_country                                                      [US]
# original_language                                                     en
# original_title                                                   Sabrina
# overview               Sabrina Fairchild, a chauffeur's daughter, gre...
# popularity                                                         2.038
# poster_path                              /i8PbLJDPU7vCwwscWD625oHbJy.jpg
# production_companies   [{'id': 4, 'logo_path': '/gz66EfNoYPqHTYI4q9UE...
# production_countries   [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
# release_date                                                  1995-12-15
# revenue                                                         53672080
# runtime                                                              127
# spoken_languages       [{'english_name': 'French', 'iso_639_1': 'fr',...
# status                                                          Released
# tagline                You are cordially invited to the most surprisi...
# title                                                            Sabrina
# video                                                              False
# vote_average                                                       6.215
# vote_count                                                           649
# movieId                                                                7
#
#                                                                        2  \
# adult                                                              False
# backdrop_path                           /lEsjVrGU21BeJjF5AF9EWsihDpw.jpg
# belongs_to_collection  {'id': 96871, 'name': 'Father of the Bride (St...
# budget                                                                 0
# genres                 [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# homepage
# id                                                                 11862
# imdb_id                                                        tt0113041
# origin_country                                                      [US]
# original_language                                                     en
# original_title                               Father of the Bride Part II
# overview               Just when George Banks has recovered from his ...
# popularity                                                        1.6479
# poster_path                             /rj4LBtwQ0uGrpBnCELr716Qo3mw.jpg
# production_companies   [{'id': 9195, 'logo_path': '/geK5QOBsXIPGHutKw...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-12-08
# revenue                                                         76594107
# runtime                                                              106
# spoken_languages       [{'english_name': 'English', 'iso_639_1': 'en'...
# status                                                          Released
# tagline                Just when his world is back to normal... he's ...
# title                                        Father of the Bride Part II
# video                                                              False
# vote_average                                                       6.252
# vote_count                                                           763
# movieId                                                                5
#
#                                                                        3  \
# adult                                                              False
# backdrop_path                           /wPSHboBNEInknw4VnCWOD2D8qc2.jpg
# belongs_to_collection                                               None
# budget                                                          35000000
# genres                 [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# homepage
# id                                                                  9091
# imdb_id                                                        tt0114576
# origin_country                                                      [US]
# original_language                                                     en
# original_title                                              Sudden Death
# overview               When a man's daughter is suddenly taken during...
# popularity                                                        2.5257
# poster_path                             /1pylO6YX5XdOA6QCc5IRxrrffkg.jpg
# production_companies   [{'id': 99689, 'logo_path': None, 'name': 'Sha...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-10-27
# revenue                                                         64350171
# runtime                                                              110
# spoken_languages       [{'english_name': 'English', 'iso_639_1': 'en'...
# status                                                          Released
# tagline                                       Terror goes into overtime.
# title                                                       Sudden Death
# video                                                              False
# vote_average                                                       5.999
# vote_count                                                           757
# movieId                                                                9
#
#                                                                        4
# adult                                                              False
# backdrop_path                           /1o4vuCHpmd4DXofMYDUwpnhKiuy.jpg
# belongs_to_collection  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                          25000000
# genres                 [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage
# id                                                                 15602
# imdb_id                                                        tt0113228
# origin_country                                                      [US]
# original_language                                                     en
# original_title                                          Grumpier Old Men
# overview               A family wedding reignites the ancient feud be...
# popularity                                                        2.9176
# poster_path                             /1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg
# production_companies   [{'id': 19464, 'logo_path': None, 'name': 'Lan...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-12-22
# revenue                                                         71500000
# runtime                                                              101
# spoken_languages       [{'english_name': 'English', 'iso_639_1': 'en'...
# status                                                          Released
# tagline                Still Yelling. Still Fighting. Still Ready for...
# title                                                   Grumpier Old Men
# video                                                              False
# vote_average                                                       6.467
# vote_count                                                           403
# movieId                                                                3

# %%
final_df[['title', 'id']].isna().sum()
# Out:
# title    0
# id       0
# dtype: int64

# %%
final_df.shape
# Out:
# (86279, 27)

# %% [markdown]
# Our final dataset contains 86,279 movies, which includes detailed information. We will save this dataset for now and proceed with preprocessing at a later stage

# %%
final_df.to_parquet('../data/raw/movies_metadata.parquet', index=False)

# %% [markdown]
# ##
